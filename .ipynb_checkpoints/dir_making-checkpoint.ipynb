# %%
import os
import numpy as np

my=['atif','bin','karim']
my=np.array(my)
print(my)
for i in my:
    print(type(i))

    dirName='F:/unreal_cv_documentation/my_dir/'+str(i)+'/'
    print("dir : ",dirName)
    print("type dir: ",type(dirName))

    if not os.path.exists(dirName):
        os.mkdir(dirName)
        print("Directory " , dirName ,  " Created ")
    else:    
        print("Directory " , dirName ,  " already exists")
# Out:
# ['atif' 'bin' 'karim']
# <class 'numpy.str_'>
# dir :  F:/unreal_cv_documentation/my_dir/atif/
# type dir:  <class 'str'>
# Directory  F:/unreal_cv_documentation/my_dir/atif/  Created
# <class 'numpy.str_'>
# dir :  F:/unreal_cv_documentation/my_dir/bin/
# type dir:  <class 'str'>
# Directory  F:/unreal_cv_documentation/my_dir/bin/  Created
# <class 'numpy.str_'>
# dir :  F:/unreal_cv_documentation/my_dir/karim/
# type dir:  <class 'str'>
# Directory  F:/unreal_cv_documentation/my_dir/karim/  Created

# %%
import json
import numpy as np
import os
import math

#config file is opening and fetching data
with open('F:/unreal_cv_documentation/capture_image_config_json/config_file_capture_image.json', 'r') as f:
    config = json.load(f)
# getting the actor name and modify them to be used in python code
# actor_name = config['DEFAULT']['actor_name']

polar_angle_start= config['DEFAULT']['polar_angle_start']
polar_angle_end = config['DEFAULT']['polar_angle_end']
azimuthal_angle_start= config['DEFAULT']['azimuthal_angle_start']
azimuthal_angle_end= config['DEFAULT']['azimuthal_angle_end']

act=len(config['actor'])
print(act)

actor_dict={}
for i in config['actor']:
    actor_dict[config['actor'][i]['actor_name']]=[]
    actor_dict[config['actor'][i]['actor_name']].append(polar_angle_start)
    actor_dict[config['actor'][i]['actor_name']].append(polar_angle_end)
    actor_dict[config['actor'][i]['actor_name']].append(azimuthal_angle_start)
    actor_dict[config['actor'][i]['actor_name']].append(azimuthal_angle_end)
    actor_dict[config['actor'][i]['actor_name']].append(config['actor'][i]['radius'])


print('now: ',actor_dict)
# Out:
# 4
# now:  {'chair_15': [90, 80, 0, 2, 350], 'SM_TableRound_2': [90, 80, 0, 2, 250], 'SM_SomatClassic_2': [90, 80, 0, 2, 150], 'SM': [90, 80, 0, 2, 10]}

# %%
def printinfo( arg1, *vartuple ):
    "This prints a variable passed arguments"
    print ("Output is: ")
    print (arg1)
    for var in vartuple:
        print (var)
    arg1_1=arg1*2;
    return arg1_1



# Now you can call printinfo function
printinfo( arg1=10 )
printinfo( 70, 60, 50 )
# arg1_1=printinfo(2)
# arg2=arg1_1*8
# print(arg2)

for i in range(1,5,1):
    print(i)
    arg1_1=printinfo(3)
    print(arg1_1)
# Out:
# Output is:
# 10
# Output is:
# 70
# 60
# 50
# 1
# Output is:
# 3
# 6
# 2
# Output is:
# 3
# 6
# 3
# Output is:
# 3
# 6
# 4
# Output is:
# 3
# 6
# 5
# Output is:
# 3
# 6
# 6
# Output is:
# 3
# 6
# 7
# Output is:
# 3
# 6
# 8
# Output is:
# 3
# 6
# 9
# Output is:
# 3
# 6
# 10
# Output is:
# 3
# 6
# 11
# Output is:
# 3
# 6
# 12
# Output is:
# 3
# 6
# 13
# Output is:
# 3
# 6
# 14
# Output is:
# 3
# 6
# 15
# Output is:
# 3
# 6
# 16
# Output is:
# 3
# 6
# 17
# Output is:
# 3
# 6
# 18
# Output is:
# 3
# 6
# 19
# Output is:
# 3
# 6
# 20
# Output is:
# 3
# 6
# 21
# Output is:
# 3
# 6
# 22
# Output is:
# 3
# 6
# 23
# Output is:
# 3
# 6
# 24
# Output is:
# 3
# 6
# 25
# Output is:
# 3
# 6
# 26
# Output is:
# 3
# 6
# 27
# Output is:
# 3
# 6
# 28
# Output is:
# 3
# 6
# 29
# Output is:
# 3
# 6
# 30
# Output is:
# 3
# 6
# 31
# Output is:
# 3
# 6
# 32
# Output is:
# 3
# 6
# 33
# Output is:
# 3
# 6
# 34
# Output is:
# 3
# 6
# 35
# Output is:
# 3
# 6
# 36
# Output is:
# 3
# 6
# 37
# Output is:
# 3
# 6
# 38
# Output is:
# 3
# 6
# 39
# Output is:
# 3
# 6
# 40
# Output is:
# 3
# 6
# 41
# Output is:
# 3
# 6
# 42
# Output is:
# 3
# 6
# 43
# Output is:
# 3
# 6
# 44
# Output is:
# 3
# 6
# 45
# Output is:
# 3
# 6
# 46
# Output is:
# 3
# 6
# 47
# Output is:
# 3
# 6
# 48
# Output is:
# 3
# 6
# 49
# Output is:
# 3
# 6

# %%
def printinfo( name, age = 35 ):
    print('passed age val is: ',k)
    "This prints a passed info into this function"
    print ("Name: ", name)
    print ("Age ", age)
    return;

for i in range(1,10,2):
    print(i)
    for k in range(1,3,1):
        print(k)
        printinfo(name='atif',age=k)
# Out:
# 1
# 1
# Name:  atif
# Age  1
# 2
# Name:  atif
# Age  2
# 3
# 1
# Name:  atif
# Age  1
# 2
# Name:  atif
# Age  2
# 5
# 1
# Name:  atif
# Age  1
# 2
# Name:  atif
# Age  2
# 7
# 1
# Name:  atif
# Age  1
# 2
# Name:  atif
# Age  2
# 9
# 1
# Name:  atif
# Age  1
# 2
# Name:  atif
# Age  2
