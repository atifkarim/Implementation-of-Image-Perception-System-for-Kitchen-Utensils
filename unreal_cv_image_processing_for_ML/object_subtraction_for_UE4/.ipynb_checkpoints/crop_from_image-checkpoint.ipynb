# %%
# import numpy as np
# import cv2
# from matplotlib import pyplot as plt
# img = cv2.imread('F:/save_image_ai/object_subtraction_for_UE4/1_mask.png')
# mask = np.zeros(img.shape[:2],np.uint8)
# bgdModel = np.zeros((1,65),np.float64)
# fgdModel = np.zeros((1,65),np.float64)
# rect = (50,50,450,290)
# cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)
# mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
# img = img*mask2[:,:,np.newaxis]
# plt.imshow(img)
# # plt.colorbar(),plt.show()

# %%
# frame = cv2.imread("F:/save_image_ai/object_subtraction_for_UE4/1_mask.png")
# lower_black = np.array([0,0,0], dtype = "uint16")q
# upper_black = np.array([70,70,70], dtype = "uint16")
# light_white = (0, 0, 200)
# dark_white = (145, 60, 255)
# # black_mask = cv2.inRange(frame, lower_black, upper_black)
# black_mask = cv2.inRange(frame, light_white,dark_white)
# frame[np.where((frame == [0]).all(axis = 2))] = [0]     # it works
# black_mask[np.where((black_mask == [0]).all(axis = 1))] = [255]
# cv2.imshow('Test', frame)
# # cv2.imshow('Test2', raw)
# if cv2.waitKey() == ord('q'):
#     cv2.destroyAllWindows()

# %%
# import cv2

# frame = cv2.imread("F:/save_image_ai/object_subtraction_for_UE4/1_mask.png")
# hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

# cv2.imshow('hsv',hsv)
# if cv2.waitKey() == ord('q'):
#     cv2.destroyAllWindows()

# %%
#  %matplotlib inline
# import cv2
# import numpy
# import matplotlib as plt

# frame = cv2.imread('F:/save_image_ai/object_subtraction_for_UE4/1_rgb.png')
# if frame is None:
#     print('Error loading image')
#     exit()

# hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

# hsv_channels = cv2.split(hsv)

# rows = frame.shape[0]
# cols = frame.shape[1]

# for i in range(0, rows):
#     for j in range(0, cols):
#         h = hsv_channels[0][i][j]

#         if h > 90 and h < 255:
#             hsv_channels[2][i][j] = 255
#         else:
#             hsv_channels[2][i][j] = 0

# cv2.imshow("original",frame)
# cv2.imshow("show0", hsv_channels[0])
# cv2.imshow("show1", hsv_channels[1])
# cv2.imshow("show2", hsv_channels[2])
# # cv2.imwrite('F:/save_image_ai/object_subtraction_for_UE4/t_1_1.png',hsv_channels[1])
# # x1=250
# # y1=200
# # x2=400
# # y2=150
# # cv2.rectangle(hsv_channels[1], (x1, y1), (x2, y2), (0,255,0), 2)
# # cv2.imwrite("F:/save_image_ai/object_subtraction_for_UE4/t_1_rec.png",hsv_channels[1])
# # cv2.imshow('rec',hsv_channels[1])

# if cv2.waitKey() == ord('q'):
#     cv2.destroyAllWindows()

# %%
# #without for loop

# %matplotlib inline
# import cv2
# import numpy
# import matplotlib as plt

# rgb_image=cv2.imread('/media/atif/0820209220208930/unreal_cv_documentation/unreal_cv_image_processing_for_ML/object_subtraction_for_UE4/1_rgb.png')
# cv2.imshow('rgb_image',rgb_image)
# frame = cv2.imread('/media/atif/0820209220208930/unreal_cv_documentation/unreal_cv_image_processing_for_ML/object_subtraction_for_UE4/1_mask.png') #load masked image
# if frame is None:
#     print('Error loading image')
#     exit()

# hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV) #convert to hsv

# hsv_channels = cv2.split(hsv) #split the hsv color

# rows = frame.shape[0]
# cols = frame.shape[1]

# cv2.imshow("mask",frame)
# cv2.imshow("show0", hsv_channels[0])
# cv2.imshow("show1", hsv_channels[1])
# # cv2.imshow("show2", hsv_channels[2])
# _,thresh=cv2.threshold(hsv_channels[1],140,255,cv2.THRESH_BINARY_INV) #thresholding done for detecting contour
# cv2.imshow('thresh',thresh)
# _, contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# cv2.drawContours(frame,contours,-1,(0,255,0),2)
# cv2.imshow('contour',frame)

# # cv2.imwrite('/media/atif/0820209220208930/unreal_cv_documentation/unreal_cv_image_processing_for_ML/object_subtraction_for_UE4/draw_rec.png',hsv_channels[1])
# x1=202
# y1=115
# x2=412
# y2=274
# cv2.rectangle(hsv_channels[1], (x1, y1), (x2, y2), (0,255,0), 2)
# cv2.rectangle(rgb_image, (x1, y1), (x2, y2), (0,255,0), 2)
# # cv2.imwrite("/media/atif/0820209220208930/unreal_cv_documentation/unreal_cv_image_processing_for_ML/object_subtraction_for_UE4/draw_rec.png",hsv_channels[1])
# cv2.imshow('rec',hsv_channels[1])
# cv2.imshow('rec_rgb',rgb_image)

# if cv2.waitKey() == ord('q'): #press q to close the output image window
#     cv2.destroyAllWindows()

# %%
# import cv2

# rgb_img = cv2.imread('F:/save_image_ai/object_subtraction_for_UE4/1_mask.png')
# gray_img=cv2.cvtColor(rgb_img,cv2.COLOR_BGR2GRAY)

# _,thresh=cv2.threshold(gray_img,225,255,cv2.THRESH_BINARY_INV)
# cv2.imshow('thresh',thresh)

# if cv2.waitKey() == ord('q'):
#     cv2.destroyAllWindows()

# %%
import numpy as np
import cv2

rgb=cv2.imread('/media/atif/0820209220208930/unreal_cv_documentation/ignore_from_git/find_coordinate/1.png')
im = cv2.imread('/media/atif/0820209220208930/unreal_cv_documentation/ignore_from_git/find_coordinate/1.png')
# imgray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)

hsv = cv2.cvtColor(im, cv2.COLOR_BGR2HSV) #convert to hsv

hsv_channels = cv2.split(hsv) #split the hsv color

# rows = im.shape[0]
# cols = im.shape[1]

# cv2.imshow("hsv_channels[1]",hsv_channels[1])  #displaying hsv image. also work for hsv_channels[0]

_,thresh=cv2.threshold(hsv_channels[1],140,255,cv2.THRESH_BINARY_INV) #do thresholding
# cv2.imshow('thresholded_image',thresh) #display thresholded image

im2, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE) #apply contour function on thresholded image
# cnt = contours[4]
#You will find contour from thresholded or canny edged image clearly. After then you can apply the detected contour on other image. Ths has done later.

# cv2.drawContours(im, contours, 0, (0,255,0), 3) #draw contour on masked image
# cv2.imshow('contoured_image_on_mask',im) #displaying contour on masked image

# cv2.drawContours(hsv_channels[1], contours, 0, (0,255,0), 3) #draw contour on hsv image
# cv2.imshow('contoured_image_hsv',hsv_channels[1]) # Displaying contour on hsv image

cnt_table = contours[0] #if you change this numeric value then you will find something interesting like it will change the position of contour
cnt_chair =contours[0]
# M = cv2.moments(cnt)
# print( M )

# k = cv2.isContourConvex(cnt_table)
# print(k)

x,y,w,h = cv2.boundingRect(cnt_chair) #this related to bound the contour on a box. It actually takes information from contour
x_t,y_t,w_t,h_t = cv2.boundingRect(cnt_table)

# cv2.rectangle(hsv_channels[1],(x,y),(x+w,y+h),(0,255,0),2) #draw this box on hsv image.
# cv2.imshow('rec_hsv[1]',hsv_channels[1])

# cv2.rectangle(thresh,(x,y),(x+w,y+h),(0,255,0),2) #draw this on thresholded image. result not good
# cv2.imshow('rec_thresh',thresh)

mask_rec_chair=cv2.rectangle(im,(x,y),(x+w,y+h),(255,255,255),1) #draw this box on masked image
cv2.imshow('rec_mask',mask_rec_chair)

mask_rec_table=cv2.rectangle(im,(x_t,y_t),(x_t+w_t,y_t+h_t),(255,255,255),1) #draw this box on masked image
cv2.imshow('rec_mask_table',mask_rec_table)

mask_rec_1=cv2.rectangle(im,(x_t,y_t),(x_t+w_t,y_t+h_t),(255,255,255),1) #draw this box on masked image
cv2.imshow('rec_mask_1',mask_rec_1)

rgb_rec_chair=cv2.rectangle(rgb,(x,y),(x+w,y+h),(255,255,255),1) #draw this box on rgb image
cv2.imshow('rec_rgb_chair',rgb_rec_chair)

rgb_rec_table=cv2.rectangle(rgb,(x_t,y_t),(x_t+w_t,y_t+h_t),(255,255,255),1) #draw this box on rgb image
cv2.imshow('rec_rgb_table',rgb_rec_table)

crop_img_chair = rgb_rec_chair[y:y+h, x:x+w] #to crop the applied bounded box
cv2.imshow("cropped_chair", crop_img_chair) #displaying cropped image
# cv2.imwrite("/media/atif/0820209220208930/unreal_cv_documentation/unreal_cv_image_processing_for_ML/object_subtraction_for_UE4/single_image_testing/crop_rgb_chair_1.png",crop_img_chair) #save the cropped image

crop_img_table = rgb_rec_table[y_t:y_t+h_t, x_t:x_t+w_t] #to crop the applied bounded box
cv2.imshow("cropped_table", crop_img_table) #displaying cropped image
# cv2.imwrite("/media/atif/0820209220208930/unreal_cv_documentation/unreal_cv_image_processing_for_ML/object_subtraction_for_UE4/single_image_testing/crop_rgb_table_1.png",crop_img_table)


if cv2.waitKey() == ord('q'): #press q to close the output image window
    cv2.destroyAllWindows()

# %%
import glob
import cv2
import numpy as np
import os

# path_mask = '/media/atif/0820209220208930/unreal_cv_documentation/unreal_cv_image_processing_for_ML/object_subtraction_for_UE4/single_image_testing/m'
# path_rgb = '/media/atif/0820209220208930/unreal_cv_documentation/unreal_cv_image_processing_for_ML/object_subtraction_for_UE4/single_image_testing/r'

path_mask = '/media/atif/0820209220208930/save_image_ai/object_subtraction_for_UE4/image_AI/mask_table_4_21'
path_rgb = '/media/atif/0820209220208930/save_image_ai/object_subtraction_for_UE4/image_AI/rgb_table_4_21'


# img_path_mask = sorted(glob.glob(path_mask+ '/*.png'))
# img_path_rgb = sorted(glob.glob(path_rgb+ '/*.png'))
for a,b,image_mask in os.walk(path_mask):
    for s in image_mask:
        n=s.split(".")
#         print(n[0])
        mask = path_mask+'/'+s
        image_mask2=cv2.imread(mask)
        hsv = cv2.cvtColor(image_mask2, cv2.COLOR_BGR2HSV)
        hsv_channels = cv2.split(hsv)

        _,thresh=cv2.threshold(hsv_channels[1],140,255,cv2.THRESH_BINARY_INV)
        im2, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        cv2.drawContours(image_mask2, contours, 0, (0,255,0), 3)
        cnt = contours[0]
#         cnt_table = contours[0]
        x,y,w,h = cv2.boundingRect(cnt)
#         x_t,y_t,w_t,h_t = cv2.boundingRect(cnt_table)
        
        for c,d,image_rgb in os.walk(path_rgb):
            for t in image_rgb:
                m=t.split('.')
                if int(n[0])== int(m[0]):
                    rgb = path_rgb+'/'+t
                    image_rgb2=cv2.imread(rgb)
                    image_rgb_rec=cv2.rectangle(image_rgb2,(x,y),(x+w,y+h),(255,255,255),1)
#                     rgb_rec_table=cv2.rectangle(image_rgb2,(x_t,y_t),(x_t+w_t,y_t+h_t),(255,255,255),1)
                    crop_img = image_rgb_rec[y:y+h, x:x+w]
#                     crop_img_table = rgb_rec_table[y_t:y_t+h_t, x_t:x_t+w_t]
                    cv2.imwrite("/media/atif/0820209220208930/unreal_cv_documentation/ignore_from_git/crop_table_4_21/"+'table_'+str(t),crop_img)
#                     cv2.imwrite("/media/atif/0820209220208930/unreal_cv_documentation/unreal_cv_image_processing_for_ML/object_subtraction_for_UE4/test_crop_multi_object/"+str(t),crop_img_table)
#                     cv2.imwrite("/media/atif/0820209220208930/unreal_cv_documentation/unreal_cv_image_processing_for_ML/object_subtraction_for_UE4/single_image_testing/test_table_chair/"+'table_'+str(t),crop_img_table)
                else:
                    pass

# %%
import glob
import cv2
import numpy as np
import os
num=1

# path_mask = '/media/atif/0820209220208930/unreal_cv_documentation/unreal_cv_image_processing_for_ML/object_subtraction_for_UE4/single_image_testing/m'
# path_rgb = '/media/atif/0820209220208930/unreal_cv_documentation/unreal_cv_image_processing_for_ML/object_subtraction_for_UE4/single_image_testing/r'

path_mask = '/media/atif/0820209220208930/save_image_ai/object_subtraction_for_UE4/image_AI/mask_table_4_21'
path_rgb = '/media/atif/0820209220208930/save_image_ai/object_subtraction_for_UE4/image_AI/rgb_table_4_21'


# img_path_mask = sorted(glob.glob(path_mask+ '/*.png'))
# img_path_rgb = sorted(glob.glob(path_rgb+ '/*.png'))
for a,b,image_mask in os.walk(path_mask):
    for s in image_mask:
        n=s.split(".")
#         print(n[0])
        mask = path_mask+'/'+s
        image_mask2=cv2.imread(mask)
        hsv = cv2.cvtColor(image_mask2, cv2.COLOR_BGR2HSV)
        hsv_channels = cv2.split(hsv)

        _,thresh=cv2.threshold(hsv_channels[1],140,255,cv2.THRESH_BINARY_INV)
        im2, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        cv2.drawContours(image_mask2, contours, 0, (0,255,0), 3)
        cnt = contours[0]
#         cnt_table = contours[0]
        x,y,w,h = cv2.boundingRect(cnt)
#         print('here the val: ',x," ",y," ",x+w," ",y+h)
#         x_t,y_t,w_t,h_t = cv2.boundingRect(cnt_table)
        
        for c,d,image_rgb in os.walk(path_rgb):
            for t in image_rgb:
                m=t.split('.')
                if int(n[0])== int(m[0]):
                    rgb = path_rgb+'/'+t
                    image_rgb2=cv2.imread(rgb)
                    image_rgb_rec=cv2.rectangle(image_rgb2,(x,y),(x+w,y+h),(255,255,255),1)
                    crop_img = image_rgb_rec[y:y+h, x:x+w]
                    print(num,' here the val: ',x," ",y," ",x+w," ",y+h)
                    f = open("/media/atif/0820209220208930/unreal_cv_documentation/ignore_from_git/find_coordinate/label_coordinate/"+'label_'+str(num)+'.txt', 'w')
                    f.write(str(num)+"\n")
                    f.write(str(x)+' ')
                    f.write(str(y)+' ')
                    f.write(str(x+w)+' ')
                    f.write(str(y+h)+' ')
                    f.close()
                    num+=1
                else:
                    pass
# Out:
# here the val:  254   168   386   258
# here the val:  262   168   394   258
# here the val:  305   181   417   255
# here the val:  305   181   417   255
# here the val:  304   181   417   255
# here the val:  304   181   416   255
# here the val:  304   181   416   255
# here the val:  304   181   416   255
# here the val:  304   182   415   255
# here the val:  304   182   415   254
# here the val:  304   182   415   254
# here the val:  303   182   414   254
# here the val:  263   168   394   258
# here the val:  303   182   414   254
# here the val:  303   182   413   254
# here the val:  303   182   413   254
# here the val:  303   183   412   254
# here the val:  302   183   412   254
# here the val:  302   183   411   254
# here the val:  302   183   411   254
# here the val:  218   178   336   256
# here the val:  218   178   336   256
# here the val:  218   177   336   256
# here the val:  212   177   331   256
# here the val:  218   177   337   256
# here the val:  218   177   337   256
# here the val:  218   177   337   256
# here the val:  218   177   337   256
# here the val:  218   176   338   256
# here the val:  218   176   338   256
# here the val:  278   170   408   258
# here the val:  218   176   338   256
# here the val:  218   176   339   256
# here the val:  218   176   339   256
# here the val:  218   176   339   256
# here the val:  218   175   339   256
# here the val:  218   175   340   256
# here the val:  218   175   340   256
# here the val:  218   175   341   256
# here the val:  218   175   341   256
# here the val:  291   172   417   257
# here the val:  292   172   418   257
# here the val:  258   168   389   258
# here the val:  292   172   418   257
# here the val:  293   173   419   257
# here the val:  293   173   419   257
# here the val:  294   173   419   257
# here the val:  294   173   419   257
# here the val:  295   173   420   257
# here the val:  295   173   420   257
# here the val:  296   174   420   257
# here the val:  296   174   420   257
# here the val:  297   174   421   257
# here the val:  258   168   390   258
# here the val:  297   174   421   256
# here the val:  298   174   421   256
# here the val:  298   174   421   256
# here the val:  299   175   421   256
# here the val:  299   175   422   256
# here the val:  299   175   422   256
# here the val:  300   175   422   256
# here the val:  301   175   422   256
# here the val:  301   176   422   256
# here the val:  259   168   391   258
# here the val:  301   176   422   256
# here the val:  301   176   422   256
# here the val:  302   176   422   256
# here the val:  302   176   422   256
# here the val:  296   176   416   256
# here the val:  303   177   422   256
# here the val:  303   177   422   256
# here the val:  303   177   422   256
# here the val:  303   177   422   256
# here the val:  303   177   422   256
# here the val:  260   168   392   258
# here the val:  304   177   422   256
# here the val:  304   178   422   256
# here the val:  304   178   422   256
# here the val:  304   178   422   256
# here the val:  304   178   421   256
# here the val:  304   178   421   256
# here the val:  304   178   421   255
# here the val:  305   179   421   255
# here the val:  305   179   421   255
# here the val:  305   179   421   255
# here the val:  261   168   393   258
# here the val:  305   179   420   255
# here the val:  305   179   420   255
# here the val:  305   179   420   255
# here the val:  305   180   420   255
# here the val:  305   180   419   255
# here the val:  305   180   419   255
# here the val:  305   180   419   255
# here the val:  305   180   419   255
# here the val:  305   180   418   255
# here the val:  305   181   418   255
# here the val:  301   183   410   254
# here the val:  301   183   409   254
# here the val:  264   168   395   258
# here the val:  301   183   409   254
# here the val:  301   184   408   254
# here the val:  295   184   402   254
# here the val:  300   184   407   254
# here the val:  300   184   407   254
# here the val:  299   184   406   254
# here the val:  299   184   406   254
# here the val:  298   184   405   254
# here the val:  298   184   404   254
# here the val:  298   185   404   254
# here the val:  264   168   396   258
# here the val:  297   185   403   254
# here the val:  297   185   403   254
# here the val:  297   185   402   254
# here the val:  296   185   402   254
# here the val:  296   185   401   254
# here the val:  295   185   400   254
# here the val:  302   183   410   254
# here the val:  295   185   400   254
# here the val:  285   187   388   254
# here the val:  274   187   375   253
# here the val:  262   187   363   253
# here the val:  250   186   352   254
# here the val:  238   185   343   254
# here the val:  275   169   405   258
# here the val:  277   170   407   258
# here the val:  218   175   341   256
# here the val:  224   172   351   257
# here the val:  234   169   365   257
# here the val:  290   172   417   257
# here the val:  300   175   422   256
# here the val:  295   185   399   254
# here the val:  294   185   399   254
# here the val:  294   186   398   254
# here the val:  265   168   397   258
# here the val:  293   186   397   254
# here the val:  293   186   397   254
# here the val:  292   186   396   254
# here the val:  292   186   396   254
# here the val:  291   186   395   254
# here the val:  291   186   394   254
# here the val:  290   186   394   254
# here the val:  290   186   393   254
# here the val:  289   186   392   254
# here the val:  289   186   392   254
# here the val:  266   169   398   258
# here the val:  283   186   386   254
# here the val:  288   186   390   254
# here the val:  287   186   390   254
# here the val:  286   187   389   254
# here the val:  286   187   388   254
# here the val:  285   187   387   253
# here the val:  284   187   386   253
# here the val:  284   187   386   253
# here the val:  283   187   385   253
# here the val:  267   169   398   258
# here the val:  283   187   384   253
# here the val:  282   187   384   253
# here the val:  281   187   383   253
# here the val:  281   187   382   253
# here the val:  280   187   382   253
# here the val:  280   187   381   253
# here the val:  279   187   380   253
# here the val:  278   187   380   253
# here the val:  278   187   379   253
# here the val:  277   187   378   253
# here the val:  268   169   399   258
# here the val:  277   187   378   253
# here the val:  276   187   377   253
# here the val:  275   187   376   253
# here the val:  275   187   376   253
# here the val:  273   187   374   253
# here the val:  273   187   374   253
# here the val:  272   187   373   253
# here the val:  271   187   372   253
# here the val:  271   187   372   253
# here the val:  269   169   400   258
# here the val:  270   187   371   253
# here the val:  264   187   365   253
# here the val:  269   187   370   253
# here the val:  268   187   369   253
# here the val:  268   187   369   253
# here the val:  267   187   368   253
# here the val:  266   187   367   253
# here the val:  266   187   367   253
# here the val:  265   187   366   253
# here the val:  264   187   365   253
# here the val:  270   169   401   258
# here the val:  264   187   365   253
# here the val:  263   187   364   253
# here the val:  262   187   363   253
# here the val:  261   187   362   253
# here the val:  260   187   362   253
# here the val:  260   187   361   253
# here the val:  259   187   360   253
# here the val:  258   187   360   253
# here the val:  258   187   359   253
# here the val:  255   168   387   258
# here the val:  270   169   401   258
# here the val:  257   187   359   253
# here the val:  256   187   358   253
# here the val:  256   187   357   253
# here the val:  255   187   357   253
# here the val:  254   187   356   253
# here the val:  254   187   356   253
# here the val:  253   187   355   254
# here the val:  252   187   355   254
# here the val:  252   187   354   254
# here the val:  251   187   353   254
# here the val:  271   169   402   258
# here the val:  250   186   353   254
# here the val:  249   186   352   254
# here the val:  248   186   351   254
# here the val:  248   186   351   254
# here the val:  247   186   350   254
# here the val:  246   186   350   254
# here the val:  246   186   349   254
# here the val:  245   186   349   254
# here the val:  245   186   348   254
# here the val:  272   169   403   258
# here the val:  244   186   348   254
# here the val:  243   186   347   254
# here the val:  243   186   347   254
# here the val:  242   186   346   254
# here the val:  241   185   346   254
# here the val:  241   185   345   254
# here the val:  240   185   345   254
# here the val:  240   185   345   254
# here the val:  239   185   344   254
# here the val:  238   185   344   254
# here the val:  273   169   403   258
# here the val:  237   185   343   254
# here the val:  237   185   343   254
# here the val:  236   185   342   254
# here the val:  235   184   342   254
# here the val:  235   184   341   254
# here the val:  234   184   341   254
# here the val:  234   184   341   254
# here the val:  233   184   340   254
# here the val:  233   184   340   254
# here the val:  274   169   404   258
# here the val:  232   184   340   254
# here the val:  232   184   339   254
# here the val:  231   183   339   254
# here the val:  231   183   339   254
# here the val:  230   183   339   254
# here the val:  230   183   338   254
# here the val:  229   183   338   254
# here the val:  229   183   338   254
# here the val:  228   183   338   254
# here the val:  228   183   337   254
# here the val:  227   182   337   254
# here the val:  227   182   337   255
# here the val:  226   182   337   255
# here the val:  226   182   337   255
# here the val:  225   182   336   255
# here the val:  225   182   336   255
# here the val:  225   182   336   255
# here the val:  224   181   336   255
# here the val:  224   181   336   255
# here the val:  224   181   336   255
# here the val:  275   169   406   258
# here the val:  223   181   336   255
# here the val:  223   181   335   255
# here the val:  223   181   335   255
# here the val:  222   181   335   255
# here the val:  222   180   335   255
# here the val:  221   180   335   255
# here the val:  221   180   335   255
# here the val:  221   180   335   255
# here the val:  221   180   335   255
# here the val:  220   180   335   255
# here the val:  276   169   406   258
# here the val:  220   179   335   255
# here the val:  220   179   335   255
# here the val:  220   179   335   255
# here the val:  219   179   335   255
# here the val:  219   179   335   255
# here the val:  219   179   335   255
# here the val:  219   178   335   255
# here the val:  219   178   336   255
# here the val:  219   178   336   256
# here the val:  218   178   336   256
# here the val:  256   168   388   258
# here the val:  278   170   408   258
# here the val:  219   174   342   256
# here the val:  219   174   342   256
# here the val:  219   174   343   256
# here the val:  219   174   343   257
# here the val:  219   174   344   257
# here the val:  220   174   344   257
# here the val:  220   173   345   257
# here the val:  220   173   345   257
# here the val:  221   173   346   257
# here the val:  221   173   346   257
# here the val:  279   170   409   257
# here the val:  221   173   347   257
# here the val:  221   173   347   257
# here the val:  222   172   348   257
# here the val:  222   172   348   257
# here the val:  223   172   349   257
# here the val:  223   172   350   257
# here the val:  223   172   350   257
# here the val:  224   172   351   257
# here the val:  225   171   352   257
# here the val:  280   170   409   257
# here the val:  225   171   353   257
# here the val:  226   171   353   257
# here the val:  226   171   354   257
# here the val:  227   171   355   257
# here the val:  227   171   355   257
# here the val:  228   171   356   257
# here the val:  228   170   357   257
# here the val:  229   170   358   257
# here the val:  229   170   358   257
# here the val:  230   170   359   257
# here the val:  281   170   410   257
# here the val:  230   170   360   257
# here the val:  231   170   361   257
# here the val:  232   170   361   257
# here the val:  232   170   362   257
# here the val:  233   170   363   257
# here the val:  234   169   364   257
# here the val:  235   169   365   258
# here the val:  236   169   366   257
# here the val:  236   169   367   258
# here the val:  282   170   411   257
# here the val:  237   169   368   258
# here the val:  238   169   369   257
# here the val:  239   169   370   258
# here the val:  239   169   370   258
# here the val:  240   169   371   257
# here the val:  241   169   372   258
# here the val:  242   169   373   257
# here the val:  242   169   374   257
# here the val:  243   169   375   257
# here the val:  244   168   376   257
# here the val:  282   170   411   257
# here the val:  245   168   376   257
# here the val:  246   168   377   257
# here the val:  246   168   378   257
# here the val:  247   168   379   258
# here the val:  248   168   380   258
# here the val:  242   168   374   258
# here the val:  250   168   382   258
# here the val:  251   168   382   258
# here the val:  252   168   383   258
# here the val:  252   168   384   258
# here the val:  283   170   412   257
# here the val:  253   168   385   258
# here the val:  277   171   406   257
# here the val:  285   171   413   257
# here the val:  285   171   413   257
# here the val:  257   168   388   258
# here the val:  286   171   414   257
# here the val:  287   171   414   257
# here the val:  287   171   415   257
# here the val:  288   171   415   257
# here the val:  289   172   416   257
# here the val:  289   172   416   257
# here the val:  290   172   417   257

# %%
print('here the val: ',x," ",y," ",x+w," ",y+h)
